# %% [markdown]
# # **Introducción**
# El mapa de calor es una imagen que usa colores para mostrar cómo se relacionan varias variables entre sí. Cuanto más fuerte es la relación, más intenso es el color, asi mismo el coeficiente de correlación mide la relación lineal entre dos variables sus valores varían entre -1 y 1. Un valor cercano a 1 indica que su  correlación es fuerte ybpositiva, y un valor cercano a -1 sugiere una  correlación fuerte y negativa. Finalmente la La tabla ANOVA nos sirve para comparar los promedios de tres o más grupos y ver si hay diferencias importantes entre ellos.
#
# El conjunto de datos Mental Health and Lifestyle Habits Dataset (2019–2024) es una base de datos  busca entender cómo los hábitos de vida afectan la salud mental. Incluye datos como ejercicio, alimentación, sueño, estrés y relaciones sociales. Con esto podemos ver como nuestras acciones diarias están relacionadas con nuestro bienestar emocional.
#
# # **Hipótesis**
# Podria existir una correlación positiva entre los buenos hábitos de vida saludables como: la práctica regular de ejercicio, una alimentación equilibrada y un buen patrón de sueño y eso se puede ver en las personas que tienen los niveles más bajos de estrés y mejor salud psicológica.
#
# # **Marco Teórico: Regresión Lineal Múltiple y Correlación**
#
# ## Regresión Lineal Múltiple
#
# La regresión múltiple comprende de tres o más variables. Existe una sola variable dependiente, pero hay dos o más de tipos independiente (explicativo).
#
# La **Regresión Lineal Múltiple (RLM)** es una técnica estadística que extiende el modelo de regresión lineal simple al considerar **más de una variable independiente** para predecir una variable dependiente. El objetivo es encontrar una relación lineal entre la variable dependiente \( Y \) y un conjunto de variables independientes \( X_1, X_2, ..., X_n \).
#
# El modelo general se expresa como:
#
# \[
# Y = \beta_0 + \beta_1X_1 + \beta_2X_2 + \ldots + \beta_nX_n + \error
# \]
#
# Formula : 𝑌=𝛽0 + 𝛽1𝑋1 +𝛽2𝑋2 + … + 𝛽𝑛𝑋𝑛 + 𝜖
#
#
# Donde:
# - \( Y \) es la variable dependiente (respuesta),
# - \( \beta_0 \) es la ordenada al origen (intercepto),
# - \( \beta_1, \beta_2, ..., \beta_n \) son los coeficientes de regresión (pendientes),
# - \( X_1, X_2, ..., X_n \) son las variables independientes (predictoras),
# - \( \error \) es el término de error.
#
# ### Supuestos del Modelo de RLM
#
# 1. Linealidad entre las variables independientes y la dependiente.
# 2. Independencia de los errores.
# 3. Homocedasticidad (varianza constante del error).
# 4. Normalidad de los errores.
# 5. No multicolinealidad entre las variables independientes.
#
# ### Evaluación del Modelo
#
# - **\( R^2 \) (Coeficiente de determinación):** Indica qué proporción de la variación de \( Y \) es explicada por las variables independientes.
# - **Prueba F:** Evalúa si el modelo en su conjunto es significativo.
# - **p-values:** Evalúan la significancia de cada coeficiente.
#
# ## Correlación
#
# La **correlación** mide la fuerza y dirección de la relación lineal entre dos variables cuantitativas. El coeficiente de correlación más común es el **coeficiente de correlación de Pearson (r)**, que varía entre -1 y 1:
#
# - \( r = 1 \): Correlación positiva perfecta.
# - \( r = -1 \): Correlación negativa perfecta.
# - \( r = 0 \): No hay correlación lineal.
#
# ### Interpretación del Valor de r
#
# | Valor de r | Interpretación              |
# |------------|-----------------------------|
# | 0.9 – 1.0  | Correlación muy fuerte      |
# | 0.7 – 0.9  | Correlación fuerte          |
# | 0.5 – 0.7  | Correlación moderada        |
# | 0.3 – 0.5  | Correlación débil           |
# | 0.0 – 0.3  | Correlación muy débil o nula|
#
# ### Aplicaciones
#
# La RLM y la correlación se utilizan ampliamente en diversas áreas como:
# - Economía (para predecir consumo, inversión, etc.),
# - Medicina (efectos de múltiples factores sobre una enfermedad),
# - Ingeniería (modelos de predicción de fallas o calidad),
# - Ciencias sociales (relación entre nivel educativo, ingresos, etc.).
#
# https://www.ugr.es/~montero/matematicas/regresion_lineal.pdf
#
# https://prezi.com/p/urnolrdufkcs/un-2-regresion-lineal-multiple-y-correlacion/
#
# https://www.ibm.com/docs/es/cognos-analytics/11.1.x?topic=tests-multiple-linear-regression
#
# # **Metodología**
#
# 1. Seleccionar la variable dependiente.
# 2. Eliminar los datos que están incompletos.
# 3. Convertir las variables categóricas se convierten en números.
# 4. Calcular la relación entre las variables usando una matriz de correlación.
# 5. Probar los resultados con los datos de prueba.
# 6. interpretar los resultados para ver si el modelo es útil o necesita mejoras.

# %%
import pandas as pd
df = pd.read_csv ("https://raw.githubusercontent.com/ximedav/Estadistica/refs/heads/main/Mental_Health_Lifestyle_Dataset.csv")
df.dropna(inplace = True)
df
# Out:
#         Country  Age  Gender Exercise Level   Diet Type  Sleep Hours  \
# 1     Australia   31    Male       Moderate       Vegan          4.9
# 3        Brazil   35    Male            Low       Vegan          7.2
# 4       Germany   46    Male            Low    Balanced          7.3
# 5         Japan   23   Other       Moderate    Balanced          2.7
# 6         Japan   49    Male       Moderate   Junk Food          6.6
# ...         ...  ...     ...            ...         ...          ...
# 2992        USA   57    Male       Moderate  Vegetarian          8.5
# 2995      Japan   57  Female       Moderate    Balanced          7.0
# 2997  Australia   42    Male       Moderate    Balanced          6.0
# 2998  Australia   25    Male           High        Keto          5.7
# 2999      Japan   28  Female           High       Vegan          6.9
#
#      Stress Level Mental Health Condition  Work Hours per Week  \
# 1             Low                    PTSD                   48
# ...

# %%
df.dropna(inplace = True)

# %%
df['Country'].unique()
# Out:
# array(['Australia', 'Brazil', 'Germany', 'Japan', 'India', 'Canada',
#        'USA'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Q("Happiness Score") ~ C(Country)', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                 df        sum_sq   mean_sq        F   PR(>F)
# C(Country)     6.0     24.519651  4.086609  0.62355  0.71161
# Residual    2398.0  15715.960515  6.553778      NaN      NaN

# %%
df.drop(columns=['Country'], inplace=True)
df
# Out:
#       Age  Gender Exercise Level   Diet Type  Sleep Hours Stress Level  \
# 1      31    Male       Moderate       Vegan          4.9          Low
# 3      35    Male            Low       Vegan          7.2          Low
# 4      46    Male            Low    Balanced          7.3          Low
# 5      23   Other       Moderate    Balanced          2.7     Moderate
# 6      49    Male       Moderate   Junk Food          6.6          Low
# ...   ...     ...            ...         ...          ...          ...
# 2992   57    Male       Moderate  Vegetarian          8.5          Low
# 2995   57  Female       Moderate    Balanced          7.0         High
# 2997   42    Male       Moderate    Balanced          6.0         High
# 2998   25    Male           High        Keto          5.7          Low
# 2999   28  Female           High       Vegan          6.9         High
#
#      Mental Health Condition  Work Hours per Week  \
# 1                       PTSD                   48
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Age'], kde = True, color = 'pink')

plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de edad')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Other', 'Female'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Q("Happiness Score") ~ C(Gender)', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                df        sum_sq    mean_sq         F    PR(>F)
# C(Gender)     2.0     20.213240  10.106620  1.544255  0.213683
# Residual   2402.0  15720.266926   6.544657       NaN       NaN

# %%
df.drop(columns=['Gender'], inplace=True)
df
# Out:
#       Age Exercise Level   Diet Type  Sleep Hours Stress Level  \
# 1      31       Moderate       Vegan          4.9          Low
# 3      35            Low       Vegan          7.2          Low
# 4      46            Low    Balanced          7.3          Low
# 5      23       Moderate    Balanced          2.7     Moderate
# 6      49       Moderate   Junk Food          6.6          Low
# ...   ...            ...         ...          ...          ...
# 2992   57       Moderate  Vegetarian          8.5          Low
# 2995   57       Moderate    Balanced          7.0         High
# 2997   42       Moderate    Balanced          6.0         High
# 2998   25           High        Keto          5.7          Low
# 2999   28           High       Vegan          6.9         High
#
#      Mental Health Condition  Work Hours per Week  \
# 1                       PTSD                   48
# 3                 Depression                   43
# 4                    Anxiety                   35
# ...

# %%
df['Exercise Level'].unique()
# Out:
# array(['Moderate', 'Low', 'High'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Q("Happiness Score") ~ C(Q("Exercise Level"))', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                             df        sum_sq    mean_sq         F    PR(>F)
# C(Q("Exercise Level"))     2.0     42.287141  21.143570  3.235204  0.039524
# Residual                2402.0  15698.193026   6.535468       NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Happiness Score'], groups = df['Exercise Level'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Nivel de medicion', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1  group2  meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#   High      Low  -0.3232 0.0307 -0.6227 -0.0237   True
#   High Moderate  -0.1958 0.2822 -0.4982  0.1065  False
#    Low Moderate   0.1274 0.5729 -0.1695  0.4243  False
# ------------------------------------------------------

# %%
niveles = {'Low': 100, 'Moderate': 50, 'High': 0}
df['Exercise Level'] = df['Exercise Level'].map(niveles)
df
# Out:
#       Age  Exercise Level   Diet Type  Sleep Hours Stress Level  \
# 1      31              50       Vegan          4.9          Low
# 3      35             100       Vegan          7.2          Low
# 4      46             100    Balanced          7.3          Low
# 5      23              50    Balanced          2.7     Moderate
# 6      49              50   Junk Food          6.6          Low
# ...   ...             ...         ...          ...          ...
# 2992   57              50  Vegetarian          8.5          Low
# 2995   57              50    Balanced          7.0         High
# 2997   42              50    Balanced          6.0         High
# 2998   25               0        Keto          5.7          Low
# 2999   28               0       Vegan          6.9         High
#
#      Mental Health Condition  Work Hours per Week  \
# 1                       PTSD                   48
# 3                 Depression                   43
# ...

# %%
df['Diet Type'].unique()
# Out:
# array(['Vegan', 'Balanced', 'Junk Food', 'Vegetarian', 'Keto'],
#       dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Q("Happiness Score") ~ C(Q("Diet Type"))', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                        df        sum_sq    mean_sq         F    PR(>F)
# C(Q("Diet Type"))     4.0     48.095296  12.023824  1.838929  0.118624
# Residual           2400.0  15692.384870   6.538494       NaN       NaN

# %%
df.drop(columns=['Diet Type'], inplace=True)
df
# Out:
#       Age  Exercise Level  Sleep Hours Stress Level Mental Health Condition  \
# 1      31              50          4.9          Low                    PTSD
# 3      35             100          7.2          Low              Depression
# 4      46             100          7.3          Low                 Anxiety
# 5      23              50          2.7     Moderate                 Anxiety
# 6      49              50          6.6          Low                 Anxiety
# ...   ...             ...          ...          ...                     ...
# 2992   57              50          8.5          Low              Depression
# 2995   57              50          7.0         High              Depression
# 2997   42              50          6.0         High              Depression
# 2998   25               0          5.7          Low                 Anxiety
# 2999   28               0          6.9         High              Depression
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Sleep Hours'], kde = True, color = 'pink')

plt.xlabel('Horas de sueño')
plt.ylabel('Frecuencia')
plt.title('Distribución del sueño')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df.drop(columns=['Sleep Hours'], inplace=True)
df
# Out:
#       Age  Exercise Level Stress Level Mental Health Condition  \
# 1      31              50          Low                    PTSD
# 3      35             100          Low              Depression
# 4      46             100          Low                 Anxiety
# 5      23              50     Moderate                 Anxiety
# 6      49              50          Low                 Anxiety
# ...   ...             ...          ...                     ...
# 2992   57              50          Low              Depression
# 2995   57              50         High              Depression
# 2997   42              50         High              Depression
# 2998   25               0          Low                 Anxiety
# 2999   28               0         High              Depression
#
#       Work Hours per Week  Screen Time per Day (Hours)  \
# 1                      48                          5.2
# 3                      43                          2.2
# ...

# %%
df['Stress Level'].unique()
# Out:
# array(['Low', 'Moderate', 'High'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Q("Happiness Score") ~ C(Q("Stress Level"))', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                           df        sum_sq   mean_sq         F    PR(>F)
# C(Q("Stress Level"))     2.0      2.985918  1.492959  0.227869  0.796246
# Residual              2402.0  15737.494249  6.551829       NaN       NaN

# %%
df.drop(columns=['Stress Level'], inplace=True)
df
# Out:
#       Age  Exercise Level Mental Health Condition  Work Hours per Week  \
# 1      31              50                    PTSD                   48
# 3      35             100              Depression                   43
# 4      46             100                 Anxiety                   35
# 5      23              50                 Anxiety                   50
# 6      49              50                 Anxiety                   28
# ...   ...             ...                     ...                  ...
# 2992   57              50              Depression                   48
# 2995   57              50              Depression                   29
# 2997   42              50              Depression                   23
# 2998   25               0                 Anxiety                   51
# 2999   28               0              Depression                   41
#
#       Screen Time per Day (Hours)  Social Interaction Score  Happiness Score
# ...

# %%
df['Mental Health Condition'].unique()
# Out:
# array(['PTSD', 'Depression', 'Anxiety', 'Bipolar'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Q("Happiness Score") ~ C(Q("Mental Health Condition"))', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                                      df        sum_sq   mean_sq         F  \
# C(Q("Mental Health Condition"))     3.0     18.753586  6.251195  0.954674
# Residual                         2401.0  15721.726581  6.547991       NaN
#
#                                    PR(>F)
# C(Q("Mental Health Condition"))  0.413248
# Residual                              NaN

# %%
df.drop(columns=['Mental Health Condition'], inplace=True)
df
# Out:
#       Age  Exercise Level  Work Hours per Week  Screen Time per Day (Hours)  \
# 1      31              50                   48                          5.2
# 3      35             100                   43                          2.2
# 4      46             100                   35                          3.6
# 5      23              50                   50                          3.3
# 6      49              50                   28                          7.2
# ...   ...             ...                  ...                          ...
# 2992   57              50                   48                          4.4
# 2995   57              50                   29                          4.4
# 2997   42              50                   23                          3.9
# 2998   25               0                   51                          4.3
# 2999   28               0                   41                          6.7
#
#       Social Interaction Score  Happiness Score
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Work Hours per Week'], kde = True, color = 'pink')

plt.xlabel('Horas de trabajo')
plt.ylabel('Frecuencia')
plt.title('Distribución del trabajo')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Screen Time per Day (Hours)'], kde = True, color = 'pink')

plt.xlabel('Horas de pantallas')
plt.ylabel('Frecuencia')
plt.title('Distribución del uso de pantallas')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Social Interaction Score'], kde = True, color = 'pink')

plt.xlabel('Interacción social')
plt.ylabel('Frecuencia')
plt.title('Distribución de la interacción social')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Happiness Score'], kde = True, color = 'pink')

plt.xlabel('Puntuación de felicidad')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Puntuación de felicidad')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
matriz_de_correlacion = df.corr()
plt.figure(figsize = (15, 9))
sns.heatmap(matriz_de_correlacion, annot = True, cmap = 'coolwarm', fmt = "0.2f", square = True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de correlacion')
# Out:
# Text(0.5, 1.0, 'Matriz de correlacion')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
import matplotlib.pyplot as plt

X = df[['Age','Exercise Level','Social Interaction Score']]
Y = df['Happiness Score']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()

Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test, Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de determinacion: {r2: 0.4f}')
# Out:
# Coeficiente de determinacion:  0.0063

# %%
b0, b1, b2, b3 = modelo.params

Fun = lambda X1, X2, X3 : b0 + b1 * X1 + b2 * X2 + b3 * X3

Fun(10, 50, 150)
# Out:
# -1.5796845800020742

# %%
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(modelo.resid, X_train_constante)
print(f'Valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}')
# Out:
# Valor-p de Breusch-Pagan:  0.8083

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_2 = ols(formula='Q("Social Interaction Score") ~ Q("Work Hours per Week") + Age',data=df).fit()

tabla_anova = sm.stats.anova_lm(modelo_2, typ=2)
print(tabla_anova)
# Out:
#                                 sum_sq      df         F    PR(>F)
# Q("Work Hours per Week")      3.654037     1.0  0.559313  0.454610
# Age                          18.771216     1.0  2.873257  0.090192
# Residual                  15692.458866  2402.0       NaN       NaN

# %%
df = df.rename(columns={
    "Social Interaction Score": "Social_Score",
    "Work Hours per Week": "Work_Hours"
})
# es lo mismo de arriba solo lo reenombre

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm
modelo_2 = ols(formula='Social_Score ~ Work_Hours + Age', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_2, typ=2)
print(tabla_anova)
# Out:
#                   sum_sq      df         F    PR(>F)
# Work_Hours      3.654037     1.0  0.559313  0.454610
# Age            18.771216     1.0  2.873257  0.090192
# Residual    15692.458866  2402.0       NaN       NaN

# %% [markdown]
# # **Conclusión:**
#
#
# Al analizar el conjunto de datos sobre salud mental y hábitos de vida, se observó que las correlaciones entre variables como el ejercicio, la interacción social y la edad son muy bajas. Esto indica que dichas variables no están fuertemente relacionadas entre sí ni con el estado psicológico de las personas. En consecuencia, se interpreta que realizar ejercicio o tener una vida social más activa no necesariamente guarda una relación clara con el bienestar mental de los individuos.
#
# En el modelo de regresión, el coeficiente de determinación fue de apenas 0.0063, lo que significa que el modelo solo explica el 0.63% del comportamiento de la variable dependiente. Este resultado evidencia que el modelo prácticamente no logra explicar la variabilidad de dicha variable, por lo que se considera conveniente probar con otro tipo de modelo o incorporar nuevas variables.
# Finalmente, la prueba de Breusch-Pagan arrojó un valor-p de 0.8083, por lo que no se rechaza la hipótesis nula. Esto sugiere que no existen problemas de heterocedasticidad en el modelo.
#
# Como conclusión, el análisis nos muestra que las variables consideradas no se relacionan de forma significativa con el estado psicológico, y el modelo de regresión utilizado no logra explicar la variable.Lo que plantea la necesidad de usar otro modelo para ver si asi se logra explicar mejor  los factores que influyen en la salud mental.
