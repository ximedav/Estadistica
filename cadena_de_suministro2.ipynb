# %%
import pandas as pd
df = pd.read_csv ("https://raw.githubusercontent.com/ximedav/Estadistica/refs/heads/main/smart_logistics_dataset.csv")
df.dropna(inplace = True)
df
# Out:
#                Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ..                   ...       ...       ...        ...              ...
# 993  2024-10-14 10:21:17   Truck_4   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   Truck_1   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   Truck_6   89.8701    73.6867              264
# 996  2024-04-30 04:58:58   Truck_5  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   Truck_8   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 16 columns]

# %%
df.drop(columns=['Timestamp'], inplace=True)
df
# Out:
#      Asset_ID  Latitude  Longitude  Inventory_Level Shipment_Status  \
# 1     Truck_6   22.2748  -131.7086              491      In Transit
# 3     Truck_9   42.3900    -1.4788              330       Delivered
# 7     Truck_9   46.5643  -126.5348              222      In Transit
# 9     Truck_2   54.1683  -135.2676              389      In Transit
# 11   Truck_10  -25.2768   156.1262              234       Delivered
# ..        ...       ...        ...              ...             ...
# 993   Truck_4   46.9729   -36.5198              420         Delayed
# 994   Truck_1   44.2477   175.0702              143       Delivered
# 995   Truck_6   89.8701    73.6867              264       Delivered
# 996   Truck_5  -10.4792  -177.1239              479       Delivered
# 999   Truck_8   59.8356  -114.4198              157         Delayed
#
#      Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1           22.5      54.3          Heavy            16
# 3           25.4      52.3          Heavy            37
# 7           23.3      64.2         Detour            30
# 9           21.9      57.3          Clear            52
# 11          29.7      63.6         Detour            13
# ..           ...       ...            ...           ...
# 993         21.6      62.8          Clear            31
# 994         21.6      64.1         Detour            32
# 995         26.9      70.0          Heavy            32
# 996         23.7      77.9         Detour            56
# 999         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 15 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Demand_Forecast	 ~ C(Asset_ID)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                 df        sum_sq      mean_sq         F    PR(>F)
# C(Asset_ID)    9.0  5.673957e+04  6304.396170  1.770907  0.070263
# Residual     727.0  2.588106e+06  3559.980922       NaN       NaN

# %%
df.drop(columns=['Asset_ID'], inplace=True)
df
# Out:
#      Latitude  Longitude  Inventory_Level Shipment_Status  Temperature  \
# 1     22.2748  -131.7086              491      In Transit         22.5
# 3     42.3900    -1.4788              330       Delivered         25.4
# 7     46.5643  -126.5348              222      In Transit         23.3
# 9     54.1683  -135.2676              389      In Transit         21.9
# 11   -25.2768   156.1262              234       Delivered         29.7
# ..        ...        ...              ...             ...          ...
# 993   46.9729   -36.5198              420         Delayed         21.6
# 994   44.2477   175.0702              143       Delivered         21.6
# 995   89.8701    73.6867              264       Delivered         26.9
# 996  -10.4792  -177.1239              479       Delivered         23.7
# 999   59.8356  -114.4198              157         Delayed         18.7
#
#      Humidity Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# 1        54.3          Heavy            16                      439
# 3        52.3          Heavy            37                      227
# 7        64.2         Detour            30                      459
# 9        57.3          Clear            52                      127
# 11       63.6         Detour            13                      406
# ..        ...            ...           ...                      ...
# 993      62.8          Clear            31                      242
# 994      64.1         Detour            32                      307
# 995      70.0          Heavy            32                      188
# 996      77.9         Detour            56                      276
# 999      73.6          Clear            55                      323
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Latitude'], kde = True, color = 'purple')

plt.xlabel('latitud')
plt.ylabel('Frecuencia')
plt.title('Distribución de latitud')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Longitude'], kde = True, color = 'purple')

plt.xlabel('longitud')
plt.ylabel('Frecuencia')
plt.title('Distribución de longitud')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Inventory_Level'], kde = True, color = 'purple')

plt.xlabel('Nivel de invenatrio')
plt.ylabel('Frecuencia')
plt.title('Distribución de inventario')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df['Shipment_Status'].unique()
# Out:
# array(['In Transit', 'Delivered', 'Delayed'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Demand_Forecast ~ C(Shipment_Status)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                        df        sum_sq      mean_sq         F    PR(>F)
# C(Shipment_Status)    2.0  1.475267e+03   737.633369  0.204823  0.814838
# Residual            734.0  2.643370e+06  3601.322111       NaN       NaN

# %%
df.drop(columns=['Shipment_Status'], inplace=True)
df
# Out:
#      Latitude  Longitude  Inventory_Level  Temperature  Humidity  \
# 1     22.2748  -131.7086              491         22.5      54.3
# 3     42.3900    -1.4788              330         25.4      52.3
# 7     46.5643  -126.5348              222         23.3      64.2
# 9     54.1683  -135.2676              389         21.9      57.3
# 11   -25.2768   156.1262              234         29.7      63.6
# ..        ...        ...              ...          ...       ...
# 993   46.9729   -36.5198              420         21.6      62.8
# 994   44.2477   175.0702              143         21.6      64.1
# 995   89.8701    73.6867              264         26.9      70.0
# 996  -10.4792  -177.1239              479         23.7      77.9
# 999   59.8356  -114.4198              157         18.7      73.6
#
#     Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# 1            Heavy            16                      439
# 3            Heavy            37                      227
# 7           Detour            30                      459
# 9            Clear            52                      127
# 11          Detour            13                      406
# ..             ...           ...                      ...
# 993          Clear            31                      242
# 994         Detour            32                      307
# 995          Heavy            32                      188
# 996         Detour            56                      276
# 999          Clear            55                      323
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Temperature'], kde = True, color = 'purple')

plt.xlabel('Nivel de tempertura')
plt.ylabel('Frecuencia')
plt.title('Distribución de Nivel de temperatura')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Humidity'], kde = True, color = 'purple')

plt.xlabel('Humedad')
plt.ylabel('Frecuencia')
plt.title('Distribución de humedad')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df['Traffic_Status'].unique()
# Out:
# array(['Heavy', 'Detour', 'Clear'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Demand_Forecast ~ C(Traffic_Status)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                       df        sum_sq      mean_sq         F    PR(>F)
# C(Traffic_Status)    2.0  1.996710e+03   998.355010  0.277274  0.757926
# Residual           734.0  2.642849e+06  3600.611698       NaN       NaN

# %%
df.drop(columns=['Traffic_Status'], inplace=True)
df
# Out:
#      Latitude  Longitude  Inventory_Level  Temperature  Humidity  \
# 1     22.2748  -131.7086              491         22.5      54.3
# 3     42.3900    -1.4788              330         25.4      52.3
# 7     46.5643  -126.5348              222         23.3      64.2
# 9     54.1683  -135.2676              389         21.9      57.3
# 11   -25.2768   156.1262              234         29.7      63.6
# ..        ...        ...              ...          ...       ...
# 993   46.9729   -36.5198              420         21.6      62.8
# 994   44.2477   175.0702              143         21.6      64.1
# 995   89.8701    73.6867              264         26.9      70.0
# 996  -10.4792  -177.1239              479         23.7      77.9
# 999   59.8356  -114.4198              157         18.7      73.6
#
#      Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# 1              16                      439                        7
# 3              37                      227                        5
# 7              30                      459                        9
# 9              52                      127                        7
# 11             13                      406                       10
# ..            ...                      ...                      ...
# 993            31                      242                       10
# 994            32                      307                       10
# 995            32                      188                        1
# 996            56                      276                        7
# 999            55                      323                        9
#
#     Logistics_Delay_Reason  Asset_Utilization  Demand_Forecast  \
# 1                  Weather               80.9              174
# 3                  Traffic               97.4              160
# 7                  Traffic               73.8              253
# 9       Mechanical Failure               63.1              224
# 11                 Traffic               85.5              238
# ..                     ...                ...              ...
# 993                Weather               95.6              221
# 994                Traffic               64.0              168
# 995                Weather               79.2              213
# 996                Weather               83.7              272
# 999     Mechanical Failure               81.3              141
#
#      Logistics_Delay
# 1                  1
# 3                  1
# 7                  0
# 9                  0
# 11                 0
# ..               ...
# 993                1
# 994                0
# 995                1
# 996                0
# 999                1
#
# [737 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Waiting_Time'], kde = True, color = 'purple')

plt.xlabel('Tiempo de espera')
plt.ylabel('Frecuencia')
plt.title('Distribución de la espera')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['User_Transaction_Amount'], kde = True, color = 'purple')

plt.xlabel('Monto monetario')
plt.ylabel('Frecuencia')
plt.title('Distribución del Monto monetario')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['User_Purchase_Frequency'], kde = True, color = 'purple')

plt.xlabel('Frecuencia de compras')
plt.ylabel('Frecuencia')
plt.title('Distribución del frecuencia de compras')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df['Logistics_Delay_Reason'].unique()
# Out:
# array(['Weather', 'Traffic', 'Mechanical Failure'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Demand_Forecast ~ C(Logistics_Delay_Reason)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova
# Out:
#                               df        sum_sq      mean_sq         F   PR(>F)
# C(Logistics_Delay_Reason)    2.0  4.733721e+02   236.686041  0.065697  0.93642
# Residual                   734.0  2.644372e+06  3602.687090       NaN      NaN

# %%
df.drop(columns=['Logistics_Delay_Reason'], inplace=True)
df
# Out:
#      Latitude  Longitude  Inventory_Level  Temperature  Humidity  \
# 1     22.2748  -131.7086              491         22.5      54.3
# 3     42.3900    -1.4788              330         25.4      52.3
# 7     46.5643  -126.5348              222         23.3      64.2
# 9     54.1683  -135.2676              389         21.9      57.3
# 11   -25.2768   156.1262              234         29.7      63.6
# ..        ...        ...              ...          ...       ...
# 993   46.9729   -36.5198              420         21.6      62.8
# 994   44.2477   175.0702              143         21.6      64.1
# 995   89.8701    73.6867              264         26.9      70.0
# 996  -10.4792  -177.1239              479         23.7      77.9
# 999   59.8356  -114.4198              157         18.7      73.6
#
#      Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# 1              16                      439                        7
# 3              37                      227                        5
# 7              30                      459                        9
# 9              52                      127                        7
# 11             13                      406                       10
# ..            ...                      ...                      ...
# 993            31                      242                       10
# 994            32                      307                       10
# 995            32                      188                        1
# 996            56                      276                        7
# 999            55                      323                        9
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Asset_Utilization'], kde = True, color = 'purple')

plt.xlabel('Porcentaje de utilización')
plt.ylabel('Frecuencia')
plt.title('Distribución de porcentaje de utilización')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Demand_Forecast'], kde = True, color = 'purple')

plt.xlabel('Demanda prevista')
plt.ylabel('Frecuencia')
plt.title('Distribución de demanda prevista')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Logistics_Delay'], kde = True, color = 'purple')

plt.xlabel('Retraso')
plt.ylabel('Frecuencia')
plt.title('Distribución de retraso')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df.drop(columns = ['Logistics_Delay'], inplace = True)
df
# Out:
#      Latitude  Longitude  Inventory_Level  Temperature  Humidity  \
# 1     22.2748  -131.7086              491         22.5      54.3
# 3     42.3900    -1.4788              330         25.4      52.3
# 7     46.5643  -126.5348              222         23.3      64.2
# 9     54.1683  -135.2676              389         21.9      57.3
# 11   -25.2768   156.1262              234         29.7      63.6
# ..        ...        ...              ...          ...       ...
# 993   46.9729   -36.5198              420         21.6      62.8
# 994   44.2477   175.0702              143         21.6      64.1
# 995   89.8701    73.6867              264         26.9      70.0
# 996  -10.4792  -177.1239              479         23.7      77.9
# 999   59.8356  -114.4198              157         18.7      73.6
#
#      Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# 1              16                      439                        7
# 3              37                      227                        5
# 7              30                      459                        9
# 9              52                      127                        7
# 11             13                      406                       10
# ..            ...                      ...                      ...
# 993            31                      242                       10
# 994            32                      307                       10
# 995            32                      188                        1
# 996            56                      276                        7
# 999            55                      323                        9
#
#      Asset_Utilization  Demand_Forecast
# 1                 80.9              174
# 3                 97.4              160
# 7                 73.8              253
# 9                 63.1              224
# 11                85.5              238
# ..                 ...              ...
# 993               95.6              221
# 994               64.0              168
# 995               79.2              213
# 996               83.7              272
# 999               81.3              141
#
# [737 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
matriz_de_correlacion = df.corr()
plt.figure(figsize = (15, 9))
sns.heatmap(matriz_de_correlacion, annot = True, cmap = 'coolwarm', fmt = "0.2f", square = True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de correlacion')

# En el diagrama de calor la correlación entre las variables User_Purchase_Frequency y User_Transaction_Amount tienen una alta correlación con la demanda.
# Lo que quiere decir es que entre mas compren o gasten su dinero, la ldemanda tiende a aumentar.
# Out:
# Text(0.5, 1.0, 'Matriz de correlacion')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
import matplotlib.pyplot as plt

X = df[['Asset_Utilization', 'Longitude']]
Y = df['Demand_Forecast']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()


Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test, Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de determinacion: {r2: 0.4f}')
# Out:
# Coeficiente de determinacion: -0.0045

# %%
b0, b1, b2= modelo.params

Fun = lambda X1, X2 : b0 + b1 * X1 + b2 * X2

Fun(50, 150)
# Out:
# 228.85853107380012

# %%
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(modelo.resid, X_train_constante)
print(f'Valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}')
# Out:
# Valor-p de Breusch-Pagan:  0.7766

# %%
from statsmodels.formula.api import ols

moedo_2 = ols(formula = 'User_Purchase_Frequency ~ User_Transaction_Amount +  Inventory_Level +  Waiting_Time + Latitude + Asset_Utilization', data = df).fit()
tabla_anova = sm.stats.anova_lm(moedo_2, typ = 2)  # ANOVA de una via
tabla_anova
# Out:
#                               sum_sq     df             F    PR(>F)
# User_Transaction_Amount    24.378126    1.0  2.748698e+00  0.097763
# Inventory_Level             2.552119    1.0  2.877581e-01  0.591824
# Waiting_Time               18.840329    1.0  2.124297e+00  0.145409
# Latitude                    0.000002    1.0  2.465960e-07  0.999604
# Asset_Utilization           4.683508    1.0  5.280779e-01  0.467649
# Residual                 6483.218153  731.0           NaN       NaN
